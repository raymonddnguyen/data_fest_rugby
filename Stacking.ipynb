# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from tqdm import tqdm_notebook

import xgboost as xgb
import lightgbm as lgb
from skopt import BayesSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, VotingClassifier, GradientBoostingClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score, GridSearchCV, train_test_split, KFold
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler, LabelEncoder
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix, classification_report
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
games = pd.read_csv('Data/games.csv')
gps = pd.read_csv('Data/gps.csv', low_memory=False)
rpe = pd.read_csv('Data/rpe.csv')
wellness = pd.read_csv('Data/wellness.csv')

# %%
wellness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5011 entries, 0 to 5010
# Data columns (total 19 columns):
# Date                   5011 non-null object
# PlayerID               5011 non-null int64
# Fatigue                5011 non-null int64
# Soreness               5011 non-null int64
# Desire                 5011 non-null int64
# Irritability           5011 non-null int64
# BedTime                5011 non-null object
# WakeTime               5011 non-null object
# SleepHours             5011 non-null float64
# SleepQuality           5011 non-null int64
# MonitoringScore        5011 non-null int64
# Pain                   5011 non-null object
# Illness                5011 non-null object
# Menstruation           4995 non-null object
# Nutrition              4174 non-null object
# NutritionAdjustment    4266 non-null object
# USGMeasurement         4843 non-null object
# USG                    629 non-null float64
# TrainingReadiness      5011 non-null object
# dtypes: float64(2), int64(7), object(10)
# memory usage: 743.9+ KB

# %%
rpe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8860 entries, 0 to 8859
# Data columns (total 14 columns):
# Date                 8860 non-null object
# PlayerID             8860 non-null int64
# Training             8860 non-null object
# SessionType          7621 non-null object
# Duration             7621 non-null float64
# RPE                  7621 non-null float64
# SessionLoad          7621 non-null float64
# DailyLoad            3149 non-null float64
# AcuteLoad            4349 non-null float64
# ChronicLoad          4383 non-null float64
# AcuteChronicRatio    4349 non-null float64
# ObjectiveRating      4724 non-null float64
# FocusRating          4751 non-null float64
# BestOutOfMyself      3019 non-null object
# dtypes: float64(9), int64(1), object(4)
# memory usage: 969.1+ KB

# %%
def fill_cat_data_gb_player(data, col):
    return data.apply(lambda x: data.groupby('PlayerID')[col].value_counts()[x['PlayerID']].index[0], axis=1)

def fill_quant_data_gb_player(data, col):
    return  data[col].fillna(data.groupby(['PlayerID'])[col].transform('median'))

# %%
wellness['Menstruation'].fillna(value='No', inplace=True)
wellness['USG'] = wellness.apply(lambda x: wellness.groupby('PlayerID')['USG'].median()[x['PlayerID']], axis=1)
wellness['Nutrition'] = wellness.apply(lambda x: wellness.groupby('PlayerID')['Nutrition'].value_counts()[x['PlayerID']].index[0], axis=1)
wellness['NutritionAdjustment'] = wellness.apply(lambda x: wellness.groupby('PlayerID')['NutritionAdjustment'].value_counts()[x['PlayerID']].index[0], axis=1)
wellness['NutritionAdjustment'] = wellness.apply(lambda x: wellness.groupby('PlayerID')['NutritionAdjustment'].value_counts()[x['PlayerID']].index[0], axis=1)
wellness['USGMeasurement'].fillna(value='Yes', inplace=True)

# %%
wellness['WakeTime'] = pd.to_datetime(wellness['WakeTime'])
wellness['BedTime'] = pd.to_datetime(wellness['BedTime'])

wellness['TotalTimeSleptInSecs'] = wellness.apply(lambda x: (x['WakeTime'] - x['BedTime']).seconds, axis=1)
wellness.drop(['WakeTime', 'BedTime'], axis=1, inplace=True)

# %%
wellness['TrainingReadiness'] = wellness['TrainingReadiness'].map(lambda x: x.rstrip('%'))
wellness['TrainingReadiness'] = wellness['TrainingReadiness'].astype('int64')

# %% [markdown]
# wellness_cat_cols = wellness.columns[wellness.dtypes == 'object']
# for col in wellness_cat_cols:
#     if wellness[col].isnull().values.any():
#         wellness[col] = wellness[col].fillna(wellness.groupby('PlayerID')[col].value_counts()[]
#
# wellness['USG'] = fill_quant_data_gb_player(wellness, 'USG')

# %%
rpe['SessionType'] = fill_cat_data_gb_player(rpe, 'SessionType')
rpe['BestOutOfMyself'] = fill_cat_data_gb_player(rpe, 'BestOutOfMyself')
rpe_float_cols = rpe.columns[rpe.dtypes == 'float64']

for col in rpe_float_cols:
    if rpe[col].isnull().values.any():
        rpe[col] = fill_quant_data_gb_player(rpe, col)

# %%
temp = rpe

rpe = rpe.groupby(['Date', 'PlayerID', 'SessionType']).max().reset_index().drop(['SessionType', 'Duration', 'SessionLoad', ], axis=1)

# %%
count = pd.DataFrame(temp.groupby(['Date', 'PlayerID', 'SessionType']).count().reset_index()['SessionLoad'])
temp = temp.groupby(['Date', 'PlayerID', 'SessionType']).sum().reset_index()
temp = pd.concat([temp, pd.get_dummies(temp['SessionType'])], axis=1).drop('SessionType', axis=1)
temp['SessionCount'] = count
temp['Mobility/Recovery'] = temp.apply(lambda x: x['Mobility/Recovery'] * x['SessionLoad'], axis=1)
temp['Skills'] = temp.apply(lambda x: x['Skills'] * x['SessionLoad'], axis=1)
temp['Strength'] = temp.apply(lambda x: x['Strength'] * x['SessionLoad'], axis=1)
temp = temp.drop('SessionLoad', axis=1)


rpe['SessionLoadTotal_Mobility/Recovery'] = temp['Mobility/Recovery']
rpe['SessionLoadTotal_Skills'] = temp['Skills']
rpe['SessionLoadTotal_Strength'] = temp['Strength']
rpe['SessionCount'] = temp['SessionCount']
rpe['DurationTotal'] = temp['Duration']

# %%
def printClassificationErrors(y_test, y_pred):
    print('Confusion Matrix:')
    print(confusion_matrix(y_test, y_pred))
    print('Classification Report:')
    print(classification_report(y_test, y_pred))
    print('Accuracy Score: {}'.format(accuracy_score(y_test, y_pred)))

# %%
def oof_predictions(model, X, y, n_folds=5, shuffle=True, random_state=42, predict='hard'):
    k_folds = StratifiedKFold(n_splits=n_folds, shuffle=shuffle, random_state=random_state)
    oof_pred_array = np.zeros(len(X))
    #oof_test_array = np.zeros(len(X_test_actual))
    
    for train_index, test_index in tqdm_notebook(k_folds.split(X, y), total=n_folds):
        X_train, X_test = X.loc[train_index, ], X.loc[test_index, ]
        y_train, y_test = y.loc[train_index, ], y.loc[test_index, ]

        #_, X_test_meta = X_test_actual.loc[train_index, ], X_test_actual.loc[test_index]
        
        
        #print(X_train)
        #X_train = X_train.reindex(index=train_index)
        #y_train = y_train.reindex(index=train_index)

        model.fit(X_train, y_train)

        if predict == 'soft':
            y_pred = model.predict_proba(X_test)
            y_pred = np.array([prob[1] for prob in y_pred])
            
            #y_pred_actual = model.predict_proba(X_test_meta)
            #y_pred_actual = np.array([prob[1] for prob in y_pred_actual])
        elif predict == 'hard':
            y_pred = model.predict(X_test)
            #y_pred_actual = model.predict(X_test_meta)
        
        oof_pred_array[test_index] = y_pred
        #oof_test_array[test_index] = y_pred_actual
    
    return oof_pred_array#, oof_test_array

# %%
data = rpe.merge(wellness, how='inner', left_on=['PlayerID', 'Date'], right_on=['PlayerID', 'Date'])
data = data.groupby(['Date', 'PlayerID']).max().reset_index()
data['Date'] = pd.to_datetime(data['Date'])
numerical_features = data.columns[data.dtypes != 'object']
categorical_features = data.columns[data.dtypes == 'object']

data = pd.get_dummies(data=data, columns=categorical_features)

# %%
# Out:
# array(['2017-08-01T00:00:00.000000000', '2017-08-02T00:00:00.000000000',
#        '2017-08-03T00:00:00.000000000', '2017-08-04T00:00:00.000000000',
#        '2017-08-05T00:00:00.000000000', '2017-08-06T00:00:00.000000000',
#        '2017-08-07T00:00:00.000000000', '2017-08-08T00:00:00.000000000',
#        '2017-08-09T00:00:00.000000000', '2017-08-10T00:00:00.000000000',
#        '2017-08-11T00:00:00.000000000', '2017-08-12T00:00:00.000000000',
#        '2017-08-13T00:00:00.000000000', '2017-08-14T00:00:00.000000000',
#        '2017-08-15T00:00:00.000000000', '2017-08-16T00:00:00.000000000',
#        '2017-08-17T00:00:00.000000000', '2017-08-18T00:00:00.000000000',
#        '2017-08-19T00:00:00.000000000', '2017-08-20T00:00:00.000000000',
#        '2017-08-21T00:00:00.000000000', '2017-08-22T00:00:00.000000000',
#        '2017-08-23T00:00:00.000000000', '2017-08-24T00:00:00.000000000',
#        '2017-08-25T00:00:00.000000000', '2017-08-26T00:00:00.000000000',
#        '2017-08-27T00:00:00.000000000', '2017-08-28T00:00:00.000000000',
#        '2017-08-29T00:00:00.000000000', '2017-08-30T00:00:00.000000000',
#        '2017-08-31T00:00:00.000000000', '2017-09-01T00:00:00.000000000',
#        '2017-09-02T00:00:00.000000000', '2017-09-03T00:00:00.000000000',
#        '2017-09-04T00:00:00.000000000', '2017-09-05T00:00:00.000000000',
#        '2017-09-06T00:00:00.000000000', '2017-09-07T00:00:00.000000000',
#        '2017-09-08T00:00:00.000000000', '2017-09-09T00:00:00.000000000',
#        '2017-09-10T00:00:00.000000000', '2017-09-11T00:00:00.000000000',
#        '2017-09-12T00:00:00.000000000', '2017-09-13T00:00:00.000000000',
#        '2017-09-14T00:00:00.000000000', '2017-09-15T00:00:00.000000000',
#        '2017-09-16T00:00:00.000000000', '2017-09-17T00:00:00.000000000',
#        '2017-09-18T00:00:00.000000000', '2017-09-19T00:00:00.000000000',
#        '2017-09-20T00:00:00.000000000', '2017-09-21T00:00:00.000000000',
#        '2017-09-22T00:00:00.000000000', '2017-09-23T00:00:00.000000000',
#        '2017-09-24T00:00:00.000000000', '2017-09-25T00:00:00.000000000',
#        '2017-09-26T00:00:00.000000000', '2017-09-27T00:00:00.000000000',
#        '2017-09-28T00:00:00.000000000', '2017-09-29T00:00:00.000000000',
#        '2017-09-30T00:00:00.000000000', '2017-10-01T00:00:00.000000000',
#        '2017-10-02T00:00:00.000000000', '2017-10-03T00:00:00.000000000',
#        '2017-10-04T00:00:00.000000000', '2017-10-05T00:00:00.000000000',
#        '2017-10-06T00:00:00.000000000', '2017-10-07T00:00:00.000000000',
#        '2017-10-08T00:00:00.000000000', '2017-10-09T00:00:00.000000000',
#        '2017-10-10T00:00:00.000000000', '2017-10-11T00:00:00.000000000',
#        '2017-10-12T00:00:00.000000000', '2017-10-13T00:00:00.000000000',
#        '2017-10-14T00:00:00.000000000', '2017-10-15T00:00:00.000000000',
#        '2017-10-16T00:00:00.000000000', '2017-10-17T00:00:00.000000000',
#        '2017-10-18T00:00:00.000000000', '2017-10-19T00:00:00.000000000',
#        '2017-10-20T00:00:00.000000000', '2017-10-21T00:00:00.000000000',
#        '2017-10-22T00:00:00.000000000', '2017-10-23T00:00:00.000000000',
#        '2017-10-24T00:00:00.000000000', '2017-10-25T00:00:00.000000000',
#        '2017-10-26T00:00:00.000000000', '2017-10-27T00:00:00.000000000',
#        '2017-10-28T00:00:00.000000000', '2017-10-29T00:00:00.000000000',
#        '2017-10-30T00:00:00.000000000', '2017-10-31T00:00:00.000000000',
#        '2017-11-01T00:00:00.000000000', '2017-11-02T00:00:00.000000000',
#        '2017-11-03T00:00:00.000000000', '2017-11-04T00:00:00.000000000',
#        '2017-11-05T00:00:00.000000000', '2017-11-06T00:00:00.000000000',
#        '2017-11-07T00:00:00.000000000', '2017-11-08T00:00:00.000000000',
#        '2017-11-09T00:00:00.000000000', '2017-11-10T00:00:00.000000000',
#        '2017-11-11T00:00:00.000000000', '2017-11-12T00:00:00.000000000',
#        '2017-11-13T00:00:00.000000000', '2017-11-14T00:00:00.000000000',
#        '2017-11-15T00:00:00.000000000', '2017-11-16T00:00:00.000000000',
#        '2017-11-17T00:00:00.000000000', '2017-11-18T00:00:00.000000000',
#        '2017-11-19T00:00:00.000000000', '2017-11-20T00:00:00.000000000',
#        '2017-11-21T00:00:00.000000000', '2017-11-22T00:00:00.000000000',
#        '2017-11-23T00:00:00.000000000', '2017-11-24T00:00:00.000000000',
#        '2017-11-25T00:00:00.000000000', '2017-11-26T00:00:00.000000000',
#        '2017-11-27T00:00:00.000000000', '2017-11-28T00:00:00.000000000',
#        '2017-11-29T00:00:00.000000000', '2017-11-30T00:00:00.000000000',
#        '2017-12-01T00:00:00.000000000', '2017-12-02T00:00:00.000000000',
#        '2017-12-03T00:00:00.000000000', '2017-12-04T00:00:00.000000000',
#        '2017-12-05T00:00:00.000000000', '2017-12-06T00:00:00.000000000',
#        '2017-12-07T00:00:00.000000000', '2017-12-08T00:00:00.000000000',
#        '2017-12-09T00:00:00.000000000', '2017-12-10T00:00:00.000000000',
#        '2017-12-11T00:00:00.000000000', '2017-12-12T00:00:00.000000000',
#        '2017-12-13T00:00:00.000000000', '2017-12-14T00:00:00.000000000',
#        '2017-12-15T00:00:00.000000000', '2017-12-16T00:00:00.000000000',
#        '2017-12-17T00:00:00.000000000', '2017-12-18T00:00:00.000000000',
#        '2017-12-19T00:00:00.000000000', '2017-12-20T00:00:00.000000000',
#        '2017-12-21T00:00:00.000000000', '2017-12-22T00:00:00.000000000',
#        '2017-12-23T00:00:00.000000000', '2017-12-24T00:00:00.000000000',
#        '2017-12-25T00:00:00.000000000', '2017-12-26T00:00:00.000000000',
#        '2017-12-27T00:00:00.000000000', '2017-12-28T00:00:00.000000000',
#        '2017-12-29T00:00:00.000000000', '2017-12-30T00:00:00.000000000',
#        '2017-12-31T00:00:00.000000000', '2018-01-01T00:00:00.000000000',
#        '2018-01-02T00:00:00.000000000', '2018-01-03T00:00:00.000000000',
#        '2018-01-04T00:00:00.000000000', '2018-01-05T00:00:00.000000000',
#        '2018-01-06T00:00:00.000000000', '2018-01-07T00:00:00.000000000',
#        '2018-01-08T00:00:00.000000000', '2018-01-09T00:00:00.000000000',
#        '2018-01-10T00:00:00.000000000', '2018-01-11T00:00:00.000000000',
#        '2018-01-12T00:00:00.000000000', '2018-01-13T00:00:00.000000000',
#        '2018-01-14T00:00:00.000000000', '2018-01-15T00:00:00.000000000',
#        '2018-01-16T00:00:00.000000000', '2018-01-17T00:00:00.000000000',
#        '2018-01-18T00:00:00.000000000', '2018-01-19T00:00:00.000000000',
#        '2018-01-20T00:00:00.000000000', '2018-01-21T00:00:00.000000000',
#        '2018-01-22T00:00:00.000000000', '2018-01-23T00:00:00.000000000',
#        '2018-01-24T00:00:00.000000000', '2018-01-25T00:00:00.000000000',
#        '2018-01-26T00:00:00.000000000', '2018-01-27T00:00:00.000000000',
#        '2018-01-28T00:00:00.000000000', '2018-01-29T00:00:00.000000000',
#        '2018-01-30T00:00:00.000000000', '2018-01-31T00:00:00.000000000',
#        '2018-02-01T00:00:00.000000000', '2018-02-02T00:00:00.000000000',
#        '2018-02-03T00:00:00.000000000', '2018-02-04T00:00:00.000000000',
#        '2018-02-05T00:00:00.000000000', '2018-02-06T00:00:00.000000000',
#        '2018-02-07T00:00:00.000000000', '2018-02-08T00:00:00.000000000',
#        '2018-02-09T00:00:00.000000000', '2018-02-10T00:00:00.000000000',
#        '2018-02-11T00:00:00.000000000', '2018-02-12T00:00:00.000000000',
#        '2018-02-13T00:00:00.000000000', '2018-02-14T00:00:00.000000000',
#        '2018-02-15T00:00:00.000000000', '2018-02-16T00:00:00.000000000',
#        '2018-02-17T00:00:00.000000000', '2018-02-18T00:00:00.000000000',
#        '2018-02-19T00:00:00.000000000', '2018-02-20T00:00:00.000000000',
#        '2018-02-21T00:00:00.000000000', '2018-02-22T00:00:00.000000000',
#        '2018-02-23T00:00:00.000000000', '2018-02-24T00:00:00.000000000',
#        '2018-02-25T00:00:00.000000000', '2018-02-26T00:00:00.000000000',
#        '2018-02-27T00:00:00.000000000', '2018-02-28T00:00:00.000000000',
#        '2018-03-01T00:00:00.000000000', '2018-03-02T00:00:00.000000000',
#        '2018-03-03T00:00:00.000000000', '2018-03-04T00:00:00.000000000',
#        '2018-03-05T00:00:00.000000000', '2018-03-06T00:00:00.000000000',
#        '2018-03-07T00:00:00.000000000', '2018-03-08T00:00:00.000000000',
#        '2018-03-09T00:00:00.000000000', '2018-03-10T00:00:00.000000000',
#        '2018-03-11T00:00:00.000000000', '2018-03-12T00:00:00.000000000',
#        '2018-03-13T00:00:00.000000000', '2018-03-14T00:00:00.000000000',
#        '2018-03-15T00:00:00.000000000', '2018-03-16T00:00:00.000000000',
#        '2018-03-17T00:00:00.000000000', '2018-03-18T00:00:00.000000000',
#        '2018-03-19T00:00:00.000000000', '2018-03-20T00:00:00.000000000',
#        '2018-03-21T00:00:00.000000000', '2018-03-22T00:00:00.000000000',
#        '2018-03-23T00:00:00.000000000', '2018-03-24T00:00:00.000000000',
#        '2018-03-25T00:00:00.000000000', '2018-03-26T00:00:00.000000000',
#        '2018-03-27T00:00:00.000000000', '2018-03-28T00:00:00.000000000',
#        '2018-03-29T00:00:00.000000000', '2018-03-30T00:00:00.000000000',
#        '2018-03-31T00:00:00.000000000', '2018-04-01T00:00:00.000000000',
#        '2018-04-02T00:00:00.000000000', '2018-04-03T00:00:00.000000000',
#        '2018-04-04T00:00:00.000000000', '2018-04-05T00:00:00.000000000',
#        '2018-04-06T00:00:00.000000000', '2018-04-08T00:00:00.000000000',
#        '2018-04-09T00:00:00.000000000', '2018-04-10T00:00:00.000000000',
#        '2018-04-11T00:00:00.000000000', '2018-04-12T00:00:00.000000000',
#        '2018-04-13T00:00:00.000000000', '2018-04-14T00:00:00.000000000',
#        '2018-04-15T00:00:00.000000000', '2018-04-16T00:00:00.000000000',
#        '2018-04-17T00:00:00.000000000', '2018-04-18T00:00:00.000000000',
#        '2018-04-19T00:00:00.000000000', '2018-04-20T00:00:00.000000000',
#        '2018-04-21T00:00:00.000000000', '2018-04-22T00:00:00.000000000',
#        '2018-04-23T00:00:00.000000000', '2018-04-24T00:00:00.000000000',
#        '2018-04-25T00:00:00.000000000', '2018-04-26T00:00:00.000000000',
#        '2018-04-27T00:00:00.000000000', '2018-04-28T00:00:00.000000000',
#        '2018-04-29T00:00:00.000000000', '2018-04-30T00:00:00.000000000',
#        '2018-05-01T00:00:00.000000000', '2018-05-02T00:00:00.000000000',
#        '2018-05-03T00:00:00.000000000', '2018-05-04T00:00:00.000000000',
#        '2018-05-05T00:00:00.000000000', '2018-05-06T00:00:00.000000000',
#        '2018-05-07T00:00:00.000000000', '2018-05-08T00:00:00.000000000',
#        '2018-05-09T00:00:00.000000000', '2018-05-10T00:00:00.000000000',
#        '2018-05-11T00:00:00.000000000', '2018-05-12T00:00:00.000000000',
#        '2018-05-13T00:00:00.000000000', '2018-05-14T00:00:00.000000000',
#        '2018-05-15T00:00:00.000000000', '2018-05-16T00:00:00.000000000',
#        '2018-05-17T00:00:00.000000000', '2018-05-18T00:00:00.000000000',
#        '2018-05-19T00:00:00.000000000', '2018-05-20T00:00:00.000000000',
#        '2018-05-21T00:00:00.000000000', '2018-05-22T00:00:00.000000000',
#        '2018-05-23T00:00:00.000000000', '2018-05-24T00:00:00.000000000',
#        '2018-05-25T00:00:00.000000000', '2018-05-26T00:00:00.000000000',
#        '2018-05-27T00:00:00.000000000', '2018-05-28T00:00:00.000000000',
#        '2018-05-29T00:00:00.000000000', '2018-05-30T00:00:00.000000000',
#        '2018-05-31T00:00:00.000000000', '2018-06-01T00:00:00.000000000',
#        '2018-06-02T00:00:00.000000000', '2018-06-03T00:00:00.000000000',
#        '2018-06-04T00:00:00.000000000', '2018-06-05T00:00:00.000000000',
#        '2018-06-06T00:00:00.000000000', '2018-06-07T00:00:00.000000000',
#        '2018-06-08T00:00:00.000000000', '2018-06-09T00:00:00.000000000',
#        '2018-06-10T00:00:00.000000000', '2018-06-11T00:00:00.000000000',
#        '2018-06-12T00:00:00.000000000', '2018-06-13T00:00:00.000000000',
#        '2018-06-14T00:00:00.000000000', '2018-06-15T00:00:00.000000000',
#        '2018-06-16T00:00:00.000000000', '2018-06-17T00:00:00.000000000',
#        '2018-06-18T00:00:00.000000000', '2018-06-19T00:00:00.000000000',
#        '2018-06-20T00:00:00.000000000', '2018-06-21T00:00:00.000000000',
#        '2018-06-22T00:00:00.000000000', '2018-06-23T00:00:00.000000000',
#        '2018-06-24T00:00:00.000000000', '2018-06-25T00:00:00.000000000',
#        '2018-06-26T00:00:00.000000000', '2018-06-27T00:00:00.000000000',
#        '2018-06-28T00:00:00.000000000', '2018-06-29T00:00:00.000000000',
#        '2018-06-30T00:00:00.000000000', '2018-07-01T00:00:00.000000000',
#        '2018-07-02T00:00:00.000000000', '2018-07-03T00:00:00.000000000',
#        '2018-07-04T00:00:00.000000000', '2018-07-05T00:00:00.000000000',
#        '2018-07-06T00:00:00.000000000', '2018-07-07T00:00:00.000000000',
#        '2018-07-08T00:00:00.000000000', '2018-07-09T00:00:00.000000000',
#        '2018-07-10T00:00:00.000000000', '2018-07-11T00:00:00.000000000',
#        '2018-07-12T00:00:00.000000000', '2018-07-13T00:00:00.000000000',
#        '2018-07-14T00:00:00.000000000', '2018-07-15T00:00:00.000000000',
#        '2018-07-16T00:00:00.000000000', '2018-07-17T00:00:00.000000000',
#        '2018-07-18T00:00:00.000000000', '2018-07-19T00:00:00.000000000',
#        '2018-07-20T00:00:00.000000000', '2018-07-21T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4085 entries, 0 to 4084
# Data columns (total 42 columns):
# Date                                  4085 non-null datetime64[ns]
# PlayerID                              4085 non-null int64
# RPE                                   4085 non-null float64
# DailyLoad                             4085 non-null float64
# AcuteLoad                             4085 non-null float64
# ChronicLoad                           4085 non-null float64
# AcuteChronicRatio                     4085 non-null float64
# ObjectiveRating                       4085 non-null float64
# FocusRating                           4085 non-null float64
# SessionLoadTotal_Mobility/Recovery    4085 non-null float64
# SessionLoadTotal_Skills               4085 non-null float64
# SessionLoadTotal_Strength             4085 non-null float64
# SessionCount                          4085 non-null int64
# DurationTotal                         4085 non-null float64
# Fatigue                               4085 non-null int64
# Soreness                              4085 non-null int64
# Desire                                4085 non-null int64
# Irritability                          4085 non-null int64
# SleepHours                            4085 non-null float64
# SleepQuality                          4085 non-null int64
# MonitoringScore                       4085 non-null int64
# USG                                   4085 non-null float64
# TrainingReadiness                     4085 non-null int64
# TotalTimeSleptInSecs                  4085 non-null int64
# Training_No                           4085 non-null uint8
# Training_Yes                          4085 non-null uint8
# BestOutOfMyself_Absolutely            4085 non-null uint8
# BestOutOfMyself_Not at all            4085 non-null uint8
# BestOutOfMyself_Somewhat              4085 non-null uint8
# Pain_No                               4085 non-null uint8
# Pain_Yes                              4085 non-null uint8
# Illness_No                            4085 non-null uint8
# Illness_Slightly Off                  4085 non-null uint8
# Illness_Yes                           4085 non-null uint8
# Menstruation_No                       4085 non-null uint8
# Menstruation_Yes                      4085 non-null uint8
# Nutrition_Excellent                   4085 non-null uint8
# Nutrition_Okay                        4085 non-null uint8
# NutritionAdjustment_No                4085 non-null uint8
# NutritionAdjustment_Yes               4085 non-null uint8
# USGMeasurement_No                     4085 non-null uint8
# USGMeasurement_Yes                    4085 non-null uint8
# dtypes: datetime64[ns](1), float64(13), int64(10), uint8(18)
# memory usage: 837.8 KB

# %%
wellness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5011 entries, 0 to 5010
# Data columns (total 18 columns):
# Date                    5011 non-null object
# PlayerID                5011 non-null int64
# Fatigue                 5011 non-null int64
# Soreness                5011 non-null int64
# Desire                  5011 non-null int64
# Irritability            5011 non-null int64
# SleepHours              5011 non-null float64
# SleepQuality            5011 non-null int64
# MonitoringScore         5011 non-null int64
# Pain                    5011 non-null object
# Illness                 5011 non-null object
# Menstruation            5011 non-null object
# Nutrition               5011 non-null object
# NutritionAdjustment     5011 non-null object
# USGMeasurement          5011 non-null object
# USG                     5011 non-null float64
# TrainingReadiness       5011 non-null int64
# TotalTimeSleptInSecs    5011 non-null int64
# dtypes: float64(2), int64(9), object(7)
# memory usage: 704.8+ KB

# %%
pd.set_option('max_columns', 42)

temp = rpe

count = pd.DataFrame(rpe.groupby(['Date', 'PlayerID', 'SessionType']).count().reset_index()['SessionLoad'])
temp = rpe.groupby(['Date', 'PlayerID', 'SessionType']).sum().reset_index()
temp = pd.concat([temp, pd.get_dummies(temp['SessionType'])], axis=1).drop('SessionType', axis=1)
temp['SessionCount'] = count
temp['Mobility/Recovery'] = temp.apply(lambda x: x['Mobility/Recovery'] * x['SessionLoad'], axis=1)
temp['Skills'] = temp.apply(lambda x: x['Skills'] * x['SessionLoad'], axis=1)
temp['Strength'] = temp.apply(lambda x: x['Strength'] * x['SessionLoad'], axis=1)
temp = temp.drop('SessionLoad', axis=1)


rpe['SessionLoadTotal_Mobility/Recovery'] = temp['Mobility/Recovery']
rpe['SessionLoadTotal_Skills'] = temp['Skills']
rpe['SessionLoadTotal_Strength'] = temp['Strength']
rpe['SessionCount'] = temp['SessionCount']
rpe['DurationTotal'] = temp['Duration']
# Out:
#             Date  PlayerID  Duration   RPE  DailyLoad  AcuteLoad  ChronicLoad  \
# 0     2017-08-01         1     150.0   7.0     1105.0     368.90      332.330
# 1     2017-08-01         3     135.0  10.0     1215.0     452.10      435.805
# 2     2017-08-01         5      90.0   7.0      900.0     240.00      186.290
# 3     2017-08-01         8     135.0   5.0     1005.0     407.00      400.070
# 4     2017-08-01         9      45.0   9.0      405.0      57.90       14.460
# 5     2017-08-01        10     140.0   9.0     1160.5     352.40      308.570
# 6     2017-08-01        11     125.0   8.0     1170.0     452.80      446.470
# 7     2017-08-01        12     140.0   4.0      685.0     211.40      206.430
# 8     2017-08-01        13     150.0  11.0     1290.0     445.60      402.860
# 9     2017-08-01        15      90.0   6.0      780.0     190.90      168.750
# 10    2017-08-02         1      60.0   3.0      565.0     291.80      313.040
# 11    2017-08-02         3      60.0   3.0      180.0     122.10       30.540
# 12    2017-08-02         4      60.0   3.0      180.0      25.70        6.430
# 13    2017-08-02         5      60.0   5.0      570.0      47.10       11.790
# 14    2017-08-02         8      60.0   2.0      120.0      66.40       16.610
# 15    2017-08-02         9      45.0   4.0      540.0      57.90       14.460
# 16    2017-08-02        10      60.0   3.0      180.0     117.10       29.290
# 17    2017-08-02        11      30.0   2.0       60.0      80.00       20.000
# 18    2017-08-02        12      60.0   2.0      120.0      57.10       14.290
# 19    2017-08-02        13      75.0   4.0      690.0     479.90      411.430
# 20    2017-08-02        14      60.0   2.0      120.0      17.10        4.290
# 21    2017-08-02        15      60.0   3.0      180.0      68.60       17.140
# 22    2017-08-03         1      60.0   3.0      565.0      77.10       19.290
# 23    2017-08-03         3     180.0  13.0     1860.0     945.00      881.780
# 24    2017-08-03         5      90.0   8.0      930.0     291.50      199.140
# 25    2017-08-03         8     180.0   8.0     1800.0     850.40      809.250
# 26    2017-08-03         9     105.0  11.0     1140.0     466.50      389.710
# 27    2017-08-03        10     195.0  11.0     1761.0     742.00      626.420
# 28    2017-08-03        12     195.0   7.0     1260.0     464.20      423.220
# 29    2017-08-03        13     255.0  15.0     2475.0    1291.80     1197.330
# ...          ...       ...       ...   ...        ...        ...          ...
# 4301  2018-07-17         4      60.0   5.0      300.0     107.10      309.110
# 4302  2018-07-17         5      60.0   5.0      300.0      42.90      100.710
# 4303  2018-07-17         6      65.0  11.0     1101.0     412.90      706.000
# 4304  2018-07-17         7      75.0   6.0      450.0     205.70      401.790
# 4305  2018-07-17        10      60.0   4.0      240.0      79.30      298.570
# 4306  2018-07-17        11      90.0   5.0      450.0     210.00      391.360
# 4307  2018-07-17        13     150.0   6.0      990.0     594.20      682.110
# 4308  2018-07-17        14      90.0   5.0      450.0     137.10      330.930
# 4309  2018-07-17        15      60.0   4.0      240.0      34.30      161.680
# 4310  2018-07-17        16     100.0   4.0      801.5     453.75      756.790
# 4311  2018-07-18         1      60.0   3.0      565.0      62.10      159.460
# 4312  2018-07-18         2      45.0   4.0      572.5      82.90      316.570
# 4313  2018-07-18         3      60.0   5.0      540.0     105.00      372.250
# 4314  2018-07-18         6      50.0   5.0      731.0      52.90      333.500
# 4315  2018-07-18         7      60.0   4.5      657.5      98.60      372.860
# 4316  2018-07-18        10      60.0   4.0      520.5      79.30      271.430
# 4317  2018-07-18        11      50.0   4.0      670.0     115.70      351.360
# 4318  2018-07-18        13      30.0   0.0        0.0     138.60      280.680
# 4319  2018-07-18        16      60.0   3.0      581.5      68.60      378.210
# 4320  2018-07-19         1      60.0   3.0      180.0      87.90      140.540
# 4321  2018-07-19         2      60.0   4.0      240.0     117.10      279.960
# 4322  2018-07-19         6      70.0  17.0     1842.0     827.10     1046.540
# 4323  2018-07-19         7      60.0   5.0      300.0     141.40      342.320
# 4324  2018-07-19        10      75.0   4.0      300.0     122.10      250.000
# 4325  2018-07-19        11      90.0   5.0      450.0     180.00      325.110
# 4326  2018-07-19        13     120.0   6.0      990.0     541.30      649.250
# 4327  2018-07-19        16      60.0   4.0      240.0     102.90      348.570
# 4328  2018-07-20        11      87.0  16.0     1874.0    1019.10     1201.400
# 4329  2018-07-20        13      61.0  12.0     1206.0     910.60     1033.040
# 4330  2018-07-21        13      61.0  16.0     1346.0     974.30     1048.970
#
#       AcuteChronicRatio  ObjectiveRating  FocusRating  Mobility/Recovery  \
# 0                 4.925              0.0          0.0                0.0
# 1                 4.840             14.0         14.0                0.0
# 2                 5.090             16.0         18.0                0.0
# 3                 4.970              0.0          0.0                0.0
# 4                 4.000              0.0          0.0                0.0
# 5                 4.920              0.0         16.0                0.0
# 6                 4.880             16.0         18.0                0.0
# 7                 4.890             12.0         16.0                0.0
# 8                 4.890             16.0         14.0              840.0
# 9                 5.015             12.0         14.0                0.0
# 10                0.925              0.0          0.0                0.0
# 11                4.000              8.0          8.0                0.0
# 12                4.000              6.0          7.0                0.0
# 13                3.990              8.0          9.0                0.0
# 14                4.000              8.0          7.0                0.0
# 15                4.000              9.0          9.0                0.0
# 16                4.000             10.0          8.0                0.0
# 17                4.000              8.0         10.0                0.0
# 18                4.000              7.0          7.0                0.0
# 19                4.890             16.0         16.0              240.0
# 20                3.990              8.0         10.0                0.0
# 21                4.000              7.0          8.0                0.0
# 22                4.000             10.0         10.0                0.0
# 23                5.680             24.0         24.0                0.0
# 24                5.100             16.0         18.0                0.0
# 25                5.940             21.0         24.0                0.0
# 26                4.915             20.0         20.0                0.0
# 27                5.840             30.0         27.0                0.0
# 28                5.780             21.0         24.0                0.0
# 29                6.670             36.0         36.0             1125.0
# ...                 ...              ...          ...                ...
# 4301              0.350              7.0          8.0                0.0
# 4302              0.430              9.0          9.0                0.0
# 4303              1.120             16.0         16.0                0.0
# 4304              0.510              8.0          8.0                0.0
# 4305              0.270              8.0          8.0                0.0
# 4306              0.540              9.0          9.0                0.0
# 4307              1.760             16.0         18.0              540.0
# 4308              0.410              8.0          8.0                0.0
# 4309              0.210              8.0          9.0                0.0
# 4310              1.245             20.0         20.0              220.0
# 4311              0.390             10.0         10.0                0.0
# 4312              0.260              9.0          8.0                0.0
# 4313              0.280              8.0          8.0                0.0
# 4314              0.160              8.0          8.0                0.0
# 4315              0.260              8.0          8.0                0.0
# 4316              0.290              8.0          8.0                0.0
# 4317              0.330              8.0          9.0                0.0
# 4318              0.490              8.0          9.0                0.0
# 4319              0.180              8.0          8.0              135.0
# 4320              0.630             10.0         10.0                0.0
# 4321              0.420              9.0          8.0                0.0
# 4322              2.280             24.0         24.0                0.0
# 4323              0.410              8.0          8.0                0.0
# 4324              0.490              8.0          8.0                0.0
# 4325              0.550              9.0          9.0                0.0
# 4326              1.670             16.0         18.0              540.0
# 4327              0.300              7.0         10.0              240.0
# 4328              2.500             27.0         30.0                0.0
# 4329              2.680             24.0         27.0              306.0
# 4330              2.850             24.0         27.0              446.0
#
#       Skills  Strength  SessionCount
# 0      540.0       0.0             2
# 1        0.0     675.0             2
# 2        0.0     330.0             2
# 3      345.0       0.0             2
# 4        0.0     405.0             1
# 5        0.0     640.0             2
# 6      500.0       0.0             2
# 7        0.0     280.0             2
# 8        0.0       0.0             2
# 9      300.0       0.0             2
# 10     180.0       0.0             1
# 11       0.0     180.0             1
# 12       0.0     180.0             1
# 13       0.0     180.0             1
# 14     120.0       0.0             1
# 15       0.0     180.0             1
# 16       0.0     180.0             1
# 17      60.0       0.0             1
# 18       0.0     120.0             1
# 19       0.0       0.0             2
# 20     120.0       0.0             1
# 21     180.0       0.0             1
# 22     180.0       0.0             1
# 23       0.0     780.0             3
# 24       0.0     360.0             2
# 25     480.0       0.0             3
# 26       0.0     600.0             2
# 27       0.0     720.0             3
# 28       0.0     450.0             3
# 29       0.0       0.0             4
# ...      ...       ...           ...
# 4301     0.0     300.0             1
# 4302     0.0     300.0             1
# 4303   370.0       0.0             2
# 4304     0.0     450.0             1
# 4305     0.0     240.0             1
# 4306   450.0       0.0             1
# 4307     0.0       0.0             2
# 4308   450.0       0.0             1
# 4309   240.0       0.0             1
# 4310     0.0       0.0             2
# 4311   180.0       0.0             1
# 4312   200.0       0.0             1
# 4313     0.0     300.0             1
# 4314   240.0       0.0             1
# 4315     0.0     225.0             1
# 4316     0.0     180.0             1
# 4317   225.0       0.0             1
# 4318     0.0       0.0             1
# 4319     0.0       0.0             1
# 4320   180.0       0.0             1
# 4321   240.0       0.0             1
# 4322   380.0       0.0             3
# 4323     0.0     300.0             1
# 4324     0.0     300.0             1
# 4325   450.0       0.0             1
# 4326     0.0       0.0             2
# 4327     0.0       0.0             1
# 4328   534.0       0.0             3
# 4329     0.0       0.0             3
# 4330     0.0       0.0             3
#
# [4331 rows x 14 columns]

# %%
X = data.drop(['Fatigue', 'Date'], axis=1)
y = data['Fatigue']

# %%
columns = X.columns
mm = MinMaxScaler()
X[columns] = mm.fit_transform(X[columns])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, stratify=y)

# %%
n_folds=10

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

X_train = clean_dataset(X_train)

# %%
knn = KNeighborsClassifier(n_neighbors=8, p=1)
knn_oof_predictions = oof_predictions(knn, X, y, n_folds, predict='hard')
# Out:
# A Jupyter Widget

# %%
printClassificationErrors(y, knn_oof_predictions)
# Out:
# Confusion Matrix:
# [[  40   71   45    5    1    0    0]
#  [  34  200  252   66    0    0    0]
#  [  10  113  969  362    6    0    0]
#  [   2   24  475 1041   22    1    0]
#  [   0    5   47  122   33    4    0]
#  [   0    1    6   13   14   97    0]
#  [   0    0    0    0    3    1    0]]
# Classification Report:
#              precision    recall  f1-score   support
#
#           1       0.47      0.25      0.32       162
#           2       0.48      0.36      0.41       552
#           3       0.54      0.66      0.60      1460
#           4       0.65      0.67      0.66      1565
#           5       0.42      0.16      0.23       211
#           6       0.94      0.74      0.83       131
#           7       0.00      0.00      0.00         4
#
# avg / total       0.58      0.58      0.57      4085
#
# Accuracy Score: 0.5826193390452876

# %%
xgbc = xgb.XGBClassifier(objective='multi:softmax', 
                         colsample_bylevel=0.8, 
                         colsample_bytree=0.8, 
                         gamma=0.01, 
                         learning_rate=0.001, 
                         max_delta_step=20, 
                         max_depth=20, 
                         min_child_weight=1, 
                         n_estimators=100, 
                         reg_alpha=0, 
                         reg_lambda=1e-09, 
                         scale_pos_weight=0.5362970367111267, 
                         subsample=0.9719854748963996)

xgbc_oof_predictions = oof_predictions(xgbc, X, y, n_folds, predict='hard')
printClassificationErrors(y, xgbc_oof_predictions)
# Out:
# A Jupyter Widget
# Confusion Matrix:
# [[  62   89   11    0    0    0    0]
#  [  37  332  175    8    0    0    0]
#  [   4  111 1206  137    2    0    0]
#  [   1    7  174 1340   40    3    0]
#  [   0    0    6   96   97   12    0]
#  [   0    0    1    5   24  101    0]
#  [   0    0    0    0    1    3    0]]
# Classification Report:
#              precision    recall  f1-score   support
#
#           1       0.60      0.38      0.47       162
#           2       0.62      0.60      0.61       552
#           3       0.77      0.83      0.80      1460
#           4       0.84      0.86      0.85      1565
#           5       0.59      0.46      0.52       211
#           6       0.85      0.77      0.81       131
#           7       0.00      0.00      0.00         4
#
# avg / total       0.76      0.77      0.76      4085
#
# Accuracy Score: 0.7681762545899633

# %%
rfc = RandomForestClassifier(n_estimators=140, 
                             max_features=4, 
                             max_depth=4500, 
                             min_samples_split=16, 
                             random_state=0)

rfc_oof_predictions = oof_predictions(rfc, X, y, n_folds)
# Out:
# A Jupyter Widget

# %%
printClassificationErrors(y, rfc_oof_predictions)
# Out:
# Confusion Matrix:
# [[  29  103   29    1    0    0    0]
#  [  15  271  253   13    0    0    0]
#  [   1   90 1107  259    3    0    0]
#  [   1    5  226 1311   21    1    0]
#  [   0    0    9  127   72    3    0]
#  [   0    0    1    7   26   97    0]
#  [   0    0    0    0    3    1    0]]
# Classification Report:
#              precision    recall  f1-score   support
#
#           1       0.63      0.18      0.28       162
#           2       0.58      0.49      0.53       552
#           3       0.68      0.76      0.72      1460
#           4       0.76      0.84      0.80      1565
#           5       0.58      0.34      0.43       211
#           6       0.95      0.74      0.83       131
#           7       0.00      0.00      0.00         4
#
# avg / total       0.70      0.71      0.69      4085
#
# Accuracy Score: 0.7067319461444308

# %%
logr = LogisticRegression()

logr_oof_predictions = oof_predictions(logr, X, y, n_folds)
printClassificationErrors(y, logr_oof_predictions)
# Out:
# A Jupyter Widget
# Confusion Matrix:
# [[  12   91   57    2    0    0    0]
#  [  11  120  381   40    0    0    0]
#  [   3   47 1055  352    3    0    0]
#  [   1    3  399 1142   19    1    0]
#  [   0    0    4  170   34    3    0]
#  [   0    0    0   27   14   90    0]
#  [   0    0    0    1    2    1    0]]
# Classification Report:
#              precision    recall  f1-score   support
#
#           1       0.44      0.07      0.13       162
#           2       0.46      0.22      0.30       552
#           3       0.56      0.72      0.63      1460
#           4       0.66      0.73      0.69      1565
#           5       0.47      0.16      0.24       211
#           6       0.95      0.69      0.80       131
#           7       0.00      0.00      0.00         4
#
# avg / total       0.59      0.60      0.57      4085
#
# Accuracy Score: 0.6004895960832314

# %%
gbc = GradientBoostingClassifier(n_estimators=1000)

gbc_oof_predictions = oof_predictions(gbc, X, y, n_folds)
printClassificationErrors(y, gbc_oof_predictions)
# Out:
# A Jupyter Widget
# Confusion Matrix:
# [[  91   66    4    1    0    0    0]
#  [  44  429   78    1    0    0    0]
#  [   3   67 1325   61    4    0    0]
#  [   1    0   64 1443   50    6    1]
#  [   0    0    1   68  125   17    0]
#  [   0    0    0    3   27  101    0]
#  [   0    0    0    0    0    3    1]]
# Classification Report:
#              precision    recall  f1-score   support
#
#           1       0.65      0.56      0.60       162
#           2       0.76      0.78      0.77       552
#           3       0.90      0.91      0.90      1460
#           4       0.92      0.92      0.92      1565
#           5       0.61      0.59      0.60       211
#           6       0.80      0.77      0.78       131
#           7       0.50      0.25      0.33         4
#
# avg / total       0.86      0.86      0.86      4085
#
# Accuracy Score: 0.8604651162790697

# %%
svc = SVC(C=1, kernel='rbf', gamma=0.8)

svc_oof_predictions = oof_predictions(gbc, X, y, n_folds)
printClassificationErrors(y, svc_oof_predictions)
# Out:
# A Jupyter Widget
# Confusion Matrix:
# [[  90   66    5    1    0    0    0]
#  [  43  430   78    1    0    0    0]
#  [   3   65 1328   61    3    0    0]
#  [   1    0   65 1443   49    6    1]
#  [   0    0    1   65  125   20    0]
#  [   0    0    0    3   27  101    0]
#  [   0    0    0    0    1    3    0]]
# Classification Report:
#              precision    recall  f1-score   support
#
#           1       0.66      0.56      0.60       162
#           2       0.77      0.78      0.77       552
#           3       0.90      0.91      0.90      1460
#           4       0.92      0.92      0.92      1565
#           5       0.61      0.59      0.60       211
#           6       0.78      0.77      0.77       131
#           7       0.00      0.00      0.00         4
#
# avg / total       0.86      0.86      0.86      4085
#
# Accuracy Score: 0.8609547123623011

# %%
mlp = MLPClassifier()

mlp_oof_predictions = oof_predictions(mlp, X, y, n_folds)
printClassificationErrors(y, mlp_oof_predictions)
# Out:
# A Jupyter Widget
# Confusion Matrix:
# [[  58   89   15    0    0    0    0]
#  [  31  250  260   11    0    0    0]
#  [   6   88 1072  288    6    0    0]
#  [   1    4  205 1314   40    1    0]
#  [   0    0    2  126   75    8    0]
#  [   0    0    0    9   26   96    0]
#  [   0    0    0    0    1    3    0]]
# Classification Report:
#              precision    recall  f1-score   support
#
#           1       0.60      0.36      0.45       162
#           2       0.58      0.45      0.51       552
#           3       0.69      0.73      0.71      1460
#           4       0.75      0.84      0.79      1565
#           5       0.51      0.36      0.42       211
#           6       0.89      0.73      0.80       131
#           7       0.00      0.00      0.00         4
#
# avg / total       0.69      0.70      0.69      4085
#
# Accuracy Score: 0.7013463892288861

# %%
oof_predictions_lvl_one = pd.DataFrame(data={'knn': knn_oof_predictions, 
                                             'xgbc': xgbc_oof_predictions, 
                                             'rfc': rfc_oof_predictions, 
                                             'logr': logr_oof_predictions, 
                                             'gbc': gbc_oof_predictions, 
                                             'svc': svc_oof_predictions, 
                                             'mlp': mlp_oof_predictions})

oof_predictions_lvl_one.head()
# Out:
#    gbc  knn  logr  mlp  rfc  svc  xgbc
# 0  4.0  4.0   4.0  4.0  4.0  4.0   4.0
# 1  4.0  4.0   4.0  4.0  4.0  4.0   4.0
# 2  5.0  5.0   5.0  5.0  5.0  5.0   5.0
# 3  3.0  4.0   4.0  4.0  3.0  3.0   3.0
# 4  4.0  4.0   4.0  4.0  4.0  4.0   4.0

# %%
ITERATIONS = 100
METRIC = 'accuracy'

bayes_cv_tuner = BayesSearchCV(
    estimator = xgb.XGBClassifier(
        n_jobs = 2,
        objective = 'multi:softmax',
        eval_metric = 'mlogloss',
        silent=1,
        tree_method='approx'
    ),
    search_spaces = {
        'learning_rate': (0.01, 1.0, 'log-uniform'),
        'min_child_weight': (0, 10),
        'max_depth': (0, 50),
        'max_delta_step': (0, 20),
        'subsample': (0.01, 1.0, 'uniform'),
        'colsample_bytree': (0.01, 1.0, 'uniform'),
        'colsample_bylevel': (0.01, 1.0, 'uniform'),
        'reg_lambda': (1e-9, 1000, 'log-uniform'),
        'reg_alpha': (1e-9, 1.0, 'log-uniform'),
        'gamma': (1e-9, 0.5, 'log-uniform'),
        'min_child_weight': (0, 5),
        'n_estimators': (50, 100),
        'scale_pos_weight': (1e-6, 500, 'log-uniform')
    },    
    scoring = None,
    cv = StratifiedKFold(
        n_splits=5,
        shuffle=True,
        random_state=42
    ),
    n_jobs = 1,
    n_iter = ITERATIONS,
    verbose = 0,
    refit = True,####
    random_state = 42
)

def status_print(optim_result):
    """Status callback durring bayesian hyperparameter search"""
    
    # Get all the models tested so far in DataFrame format
    all_models = pd.DataFrame(bayes_cv_tuner.cv_results_)    
    
    # Get current parameters and the best parameters    
    best_params = pd.Series(bayes_cv_tuner.best_params_)
    print('Model #{}\nBest {}: {}\nBest params: {}\n'.format(
        len(all_models),
        METRIC,
        np.round(bayes_cv_tuner.best_score_, 5),
        bayes_cv_tuner.best_params_
    ))

# %%
result = bayes_cv_tuner.fit(oof_predictions_lvl_one.values, y.values, callback=status_print)
# Out:
# Model #1
# Best accuracy: 0.85973
# Best params: {'max_depth': 21, 'reg_lambda': 0.059360706359120489, 'colsample_bylevel': 0.41600291926478072, 'n_estimators': 87, 'learning_rate': 0.042815319280763466, 'subsample': 0.13556548021189216, 'gamma': 0.13031389926541354, 'min_child_weight': 2, 'max_delta_step': 13, 'colsample_bytree': 0.73044848574555188, 'reg_alpha': 5.4975577392897861e-07, 'scale_pos_weight': 0.060830282487222144}
#
# Model #2
# Best accuracy: 0.86193
# Best params: {'max_depth': 3, 'reg_lambda': 276.54244755742252, 'colsample_bylevel': 0.83901447199775159, 'n_estimators': 68, 'learning_rate': 0.79881794627812419, 'subsample': 0.99237105986371343, 'gamma': 4.3586846084807948e-07, 'min_child_weight': 1, 'max_delta_step': 17, 'colsample_bytree': 0.88448212460705367, 'reg_alpha': 0.00052669830037015467, 'scale_pos_weight': 0.30164107718431421}
#
# Model #3
# Best accuracy: 0.86193
# Best params: {'max_depth': 3, 'reg_lambda': 276.54244755742252, 'colsample_bylevel': 0.83901447199775159, 'n_estimators': 68, 'learning_rate': 0.79881794627812419, 'subsample': 0.99237105986371343, 'gamma': 4.3586846084807948e-07, 'min_child_weight': 1, 'max_delta_step': 17, 'colsample_bytree': 0.88448212460705367, 'reg_alpha': 0.00052669830037015467, 'scale_pos_weight': 0.30164107718431421}
#
# Model #4
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #5
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #6
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #7
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #8
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #9
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #10
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #11
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #12
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #13
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #14
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #15
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #16
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #17
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #18
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #19
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #20
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #21
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #22
# Best accuracy: 0.86316
# Best params: {'max_depth': 5, 'reg_lambda': 4.3806965488564525e-05, 'colsample_bylevel': 0.81427202847378977, 'n_estimators': 94, 'learning_rate': 0.40320839179989459, 'subsample': 0.83915488325032062, 'gamma': 0.00015936523535755285, 'min_child_weight': 4, 'max_delta_step': 10, 'colsample_bytree': 0.18015284578259511, 'reg_alpha': 0.16119803874863359, 'scale_pos_weight': 0.00093655031476542127}
#
# Model #23
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #24
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #25
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #26
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #27
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #28
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #29
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #30
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #31
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #32
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #33
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #34
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #35
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #36
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #37
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #38
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #39
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #40
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #41
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #42
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #43
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #44
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #45
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #46
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #47
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #48
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #49
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #50
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #51
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #52
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #53
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #54
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #55
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #56
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #57
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #58
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #59
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #60
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #61
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #62
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #63
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #64
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #65
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #66
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #67
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #68
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #69
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #70
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #71
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #72
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #73
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #74
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #75
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #76
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #77
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #78
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #79
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #80
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #81
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #82
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #83
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #84
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #85
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #86
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #87
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #88
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #89
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #90
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #91
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #92
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #93
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #94
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #95
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #96
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #97
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #98
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #99
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
#
# Model #100
# Best accuracy: 0.86438
# Best params: {'max_depth': 27, 'reg_lambda': 2.7734753867047086, 'colsample_bylevel': 0.26012920654788468, 'n_estimators': 95, 'learning_rate': 0.065933809331091386, 'subsample': 0.78930812848263798, 'gamma': 9.4983647417346097e-07, 'min_child_weight': 1, 'max_delta_step': 18, 'colsample_bytree': 0.57116929201603961, 'reg_alpha': 1.0, 'scale_pos_weight': 6.7583808624729357e-05}
